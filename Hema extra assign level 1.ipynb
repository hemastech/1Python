# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
num=input("Enter your institute name?:")
# Out:
# Enter your institute name?: HOPE AI

# %%
num=input("Enter your name:")
num=input("Enter your age:")
num=input("Enter your school name:")
num=input("Enter your degree:")
# Out:
# Enter your name: V.Hemalatha
# Enter your age: 29
# Enter your school name: sri vijay vidyalaya
# Enter your degree: M.Sc.,B.Ed

# %%
a=43
b=34
add=a+b
print("a=43")
print("b=34")
print("add=",add)
# Out:
# a=43
# b=34
# add= 77

# %%
a=43
b=34
sub=a-b
print("a=43")
print("b=34")
print("sub=",sub)
# Out:
# a=43
# b=34
# sub= 9

# %%
a=63
b=97
mul=a*b
print("a=63")
print("b=97")
print("mul=",mul)
# Out:
# a=63
# b=97
# mul= 6111

# %%
a=76
b=31
division=a/b
print("a=76")
print("b=31")
print("float division=",division)
# Out:
# a=76
# b=31
# float division= 2.4516129032258065

# %%
a=76
b=31
division=a//b
print("a=76")
print("b=31")
print("floor division=",division)
# Out:
# a=76
# b=31
# floor division= 2

# %%
a=76
b=31
modulo=76%31
print("a=76")
print("b=31")
print("modulo=",modulo)
# Out:
# a=76
# b=31
# modulo= 14

# %%
a=4
b=4
power=(a**b)
print("a=4")
print("b=4")
print("power=",power)
# Out:
# a=4
# b=4
# power= 256
