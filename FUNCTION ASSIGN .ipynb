# %%
def oddeven():
    num=int(input("Enter the number:"))
    if((num%2)==1):
        print("odd number")
        message="odd number"
    else:
        print("even number")
        message="even number"
    return message

# %%
 oddeven()
# Out:
# Enter the number: 52452
# even number
# 'even number'

# %%
def Elegibilityformarriage():
    gender=input("Enter your gender:")
    age=int(input("Enter your age:"))
    if gender == 'male':
        if(age <= 21):
             print("Not Elegible for marriage")
             message="Not Elegible for marriage"
        else:
             print("Elegible")
    elif gender == 'female':
        if(age <= 18):
            print("Not Elegible for marriage")
            message="Not Elegible for marriage"
        else:
            print("Elegible")

# %%
 Elegibilityformarriage()
# Out:
# Enter your gender: male
# Enter your age: 20
# Not Elegible for marriage

# %%
def SubfieldsinAI(): 
    subfields=["Machine Learning,""Neural networks","vision","Robotics","Speech Processing","Natural Language Processing"]
    print("subfields in AI are:")
    message="subfields in AI are"
    #print(subfields[])
    for x in subfields:
        print(x)

# %%
SubfieldsinAI()
# Out:
# subfields in AI are:
# Machine Learning,Neural networks
# vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
def percentage():
    a=int(input("subject1="))
    b=int(input("subject2="))
    c=int(input("subject3="))
    d=int(input("subject4="))
    e=int(input("subject5="))
    t=a+b+c+d+e
    p=t/500*100
    print("Total:",t)
    message="Total:",t
    print("percentage:",p)
    message="percentage:",p
    return message

# %%
percentage()
# Out:
# subject1= 98
# subject2= 87
# subject3= 95
# subject4= 95
# subject5= 93
# Total: 468
# percentage: 93.60000000000001
# ('percentage:', 93.60000000000001)

# %%
def triangle():
    a=int(input("Height"))
    b=int(input("Breadth"))
    c=a*b/2
    print("Area of formula:","(Height*Breadth)/2")
    message="Area of formula:","(Height*Breadth)/2"
    print("Area of Triangle:",c)
    message="Area of Triangle:",c

# %%
triangle()
# Out:
# Height 32
# Breadth 34
# Area of formula: (Height*Breadth)/2
# Area of Triangle: 544.0
